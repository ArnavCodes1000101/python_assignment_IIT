# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnavCodes1000101/python_assignment_IIT/blob/OTHERS(ITM-OR-PERSONAL-PROJECT)/python_assignment_arnav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#movie booking question

movies = {
    "avengers": 150,
    "interstellar": 180,
    "odyssey": 120,
    "spider-man": 160
}

food = {
    "Popcorn": 80,
    "Cold Drink": 50,
    "pizza": 100
}

print("Available movies")
print(movies)

while True:

    movie = input("Select the movie you want to watch: (press q to quit) ")

    if movie == "q":
        print("Thanks for visiting")
        break

    if movie in movies:
        print(f"You have selected {movie}")
        break

    else:
        print("Movie not available, please select only the movies in the list")


tickets = int(input("Enter number of tickets: "))

movie_bill = movies[movie] * tickets

print("Your movie bill is:", movie_bill)


print("Available food")
print(food)

food_item = input("Select food item: ")

quantity = int(input("Enter quantity: "))

food_bill = food[food_item] * quantity

print("Food bill is:", food_bill)


total = movie_bill + food_bill

print("FINAL BILL")
print("Movie:", movie)
print("Tickets:", tickets)
print("Movie bill:", movie_bill)
print("Food:", food_item)
print("Food bill:", food_bill)
print("Total bill:", total)
# Out:
# Available movies
# {'avengers': 150, 'interstellar': 180, 'odyssey': 120, 'spider-man': 160}
# Select the movie you want to watch: (press q to quit) avengers
# You have selected avengers
# Enter number of tickets: 50000
# Your movie bill is: 7500000
# Available food
# {'Popcorn': 80, 'Cold Drink': 50, 'pizza': 100}
# Select food item: Cold Drink
# Enter quantity: 200000000000000
# Food bill is: 10000000000000000
# FINAL BILL
# Movie: avengers
# Tickets: 50000
# Movie bill: 7500000
# Food: Cold Drink
# Food bill: 10000000000000000
# Total bill: 10000000007500000

# %%
#question 1

n = int(input("Enter a number: "))

if n % 2 == 0:
    print("Even")
else:
    print("Odd")

if n > 0:
    print("Positive")
elif n < 0:
    print("Negative")
else:
    print("Zero")

# %%
#question 2
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a == b:
    print("Both numbers are equal")
elif a > b:
    print(a, "is greater")
else:
    print(b, "is greater")

# %%
#question 3
marks = int(input("Enter marks: "))

if marks < 0 or marks > 100:
    print("Invalid marks")
elif marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Grade F")

# %%
#question 4
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a + b <= c or a + c <= b or b + c <= a:
    print("Invalid triangle")

elif a == b and b == c:
    print("Equilateral triangle")

elif a == b or b == c or a == c:
    print("Isosceles triangle")

else:
    print("Scalene triangle")

# %%
#question 5
units = int(input("Enter units consumed: "))

if units <= 100:
    bill = units * 2

elif units <= 200:
    bill = 100 * 2 + (units - 100) * 3

else:
    bill = 100 * 2 + 100 * 3 + (units - 200) * 5

print("Total bill = ₹", bill)

# %%
#question 6
marks = [78, 45, 91, 33, 67, 49]

passed = 0
failed = 0

for mark in marks:

    if mark >= 40:
        print(mark, "Pass")
        passed = passed + 1

    else:
        print(mark, "Fail")
        failed = failed + 1

print("Failed students:", failed)
print("Passed students:", passed)

print("Fail : Pass =", failed, ":", passed)

# %%
#question 7
stock = {
    "laptop": 5,
    "mouse": 0,
    "keyboard": 3,
    "monitor": 0
}

product = input("Enter product name: ")

if product not in stock:
    print("Product is not present")

elif stock[product] == 0:
    print("Product is unavailable")

else:
    print("Product is available")
    print("Quantity:", stock[product])

# %%
#question 8
balance = int(input("Enter account balance: "))
withdraw = int(input("Enter amount to withdraw: "))

if withdraw <= 0:
    print("Invalid withdrawal amount")

elif withdraw > balance:
    print("Insufficient balance")

else:
    balance = balance - withdraw
    print("Withdrawal successful")
    print("Remaining balance:", balance)

# %%
#question 9

shopping_amount = int(input("Enter shopping amount: "))

if shopping_amount <= 1000:
    discount = shopping_amount * 0

elif shopping_amount <= 4999:
    discount = shopping_amount * 0.1

elif shopping_amount <= 9999:
    discount = shopping_amount * 0.2

else:
    discount = shopping_amount * 0.3
print("actual_amount: ", shopping_amount)
print("Discount: ", discount)
print("Total amount to be paid: ", shopping_amount - discount)
# Out:
# Enter shopping amount: 7895
# actual_amount:  7895
# Discount:  1579.0
# Total amount to be paid:  6316.0

# %%
#question 10

products = {
"laptop": {"price": 50000, "stock": 3},
"phone": {"price": 30000, "stock": 5},
"headphones": {"price": 2000, "stock": 0}
}
print(products)
product = input("Enter product name: ")

if product not in products:
    print("Product not found")

elif products[product]["stock"] == 0:
    print("Product is out of stock")

else:
    print("Product is available")

quantity = int(input("Enter quantity: "))

if quantity > products[product]["stock"]:
    print("Insufficient stock")

else:
    total_price = products[product]["price"] * quantity
    print("Total price:", total_price)

if total_price >= 50000:
    discount = total_price * 0.1
    print("Discount:", discount)

final_price = total_price - discount

print("Final price:", final_price)
# Out:
# {'laptop': {'price': 50000, 'stock': 3}, 'phone': {'price': 30000, 'stock': 5}, 'headphones': {'price': 2000, 'stock': 0}}
# Enter product name: phone
# Product is available
# Enter quantity: 5
# Total price: 150000
# Discount: 15000.0
# Final price: 135000.0

# %%
#question 11
students = { "Aman": [85, 92, 78], "Riya": [95, 88, 91], "Karan": [72, 65, 80], "Simran": [45, 92, 88], "Raj": [90, 91, 95] }
scholarship = 0
highest_average = 0
highest_scorer = ""

for name, marks in students.items():
    average = sum(marks) / len(marks)

    category = ""

    if any(mark <= 40 for mark in marks):
        category = "Failed"
    else:

        if average >= 90 and all(mark >= 85 for mark in marks):
            category = "Scholarship"
            scholarship += 1
        elif average >= 80:
            category = "Distinction"
        elif average >= 60:
            category = "Pass"
        else:
            category = "Needs Improvement"

    if average > highest_average:
        highest_average = average
        highest_scorer = name

    print(name, ":", category)

print("Total Scholarship Students:", scholarship)
print("Highest Average:", highest_average)
print("Highest Scorer:", highest_scorer)
# Out:
# Aman : Distinction
# Riya : Scholarship
# Karan : Pass
# Simran : Pass
# Raj : Scholarship
# Total Scholarship Students: 2
# Highest Average: 92.0
# Highest Scorer: Raj

# %%
#bonus question
transactions = {
"Aman": [500, 1200, 300, 15000, 700],
"Riya": [200, 300, 450, 600],
"Karan": [10000, 50, 80, 12000],
"Simran": [400, 500, 600, 700]
}
print(transactions)
highest_total = 0
highest_spending_customer = ""
total_suspicious = 0

for name, amounts in transactions.items():
    total = sum(amounts)
    suspicious = 0
    for amount in amounts:
        if amount > 10000:
            suspicious = suspicious + 1

    if suspicious >= 2 or (suspicious == 1 and total > 20000):
        risk = "High Risk"
    else:
        risk = "Low Risk"

    print(name, ": ", risk)
    print("Total Spent: ", total)
    print("Suspicious Transactions: ", suspicious)
    print()

    total_suspicious = total_suspicious + suspicious
    if total > highest_total:
        highest_total = total
        highest_spending_customer = name

print("Highest Spending Customer:", highest_spending_customer)
print("Highest Total Spending:", highest_total)
print("Total Suspicious Transactions in the data: ", total_suspicious)
# Out:
# {'Aman': [500, 1200, 300, 15000, 700], 'Riya': [200, 300, 450, 600], 'Karan': [10000, 50, 80, 12000], 'Simran': [400, 500, 600, 700]}
# Aman :  Low Risk
# Total Spent:  17700
# Suspicious Transactions:  1
#
# Riya :  Low Risk
# Total Spent:  1550
# Suspicious Transactions:  0
#
# Karan :  High Risk
# Total Spent:  22130
# Suspicious Transactions:  1
#
# Simran :  Low Risk
# Total Spent:  2200
# Suspicious Transactions:  0
#
# Highest Spending Customer: Karan
# Highest Total Spending: 22130
# Total Suspicious Transactions: 2
