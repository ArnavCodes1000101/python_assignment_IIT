# %% [markdown]
# <a href="https://colab.research.google.com/github/ArnavCodes1000101/python_assignment_IIT/blob/OTHERS(ITM-OR-Assignment_by_student_coaches)/movie_ticket_booking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#movie booking question

movies = {
    "avengers": 150,
    "interstellar": 180,
    "odyssey": 120,
    "spider-man": 160
}

food = {
    "Popcorn": 80,
    "Cold Drink": 50,
    "pizza": 100
}

print("Available movies")
print(movies)

while True:

    movie = input("Select the movie you want to watch: (press q to quit) ")

    if movie == "q":
        print("Thanks for visiting")
        break

    if movie in movies:
        print(f"You have selected {movie}")
        break

    else:
        print("Movie not available, please select only the movies in the list")


tickets = int(input("Enter number of tickets: "))

movie_bill = movies[movie] * tickets

print("Your movie bill is:", movie_bill)


print("Available food")
print(food)

food_item = input("Select food item: ")

quantity = int(input("Enter quantity: "))

food_bill = food[food_item] * quantity

print("Food bill is:", food_bill)


total = movie_bill + food_bill

print("FINAL BILL")
print("Movie:", movie)
print("Tickets:", tickets)
print("Movie bill:", movie_bill)
print("Food:", food_item)
print("Food bill:", food_bill)
print("Total bill:", total)
# Out:
# Available movies
# {'avengers': 150, 'interstellar': 180, 'odyssey': 120, 'spider-man': 160}
# Select the movie you want to watch: (press q to quit) avengers
# You have selected avengers
# Enter number of tickets: 2
# Your movie bill is: 300
# Available food
# {'Popcorn': 80, 'Cold Drink': 50, 'pizza': 100}
# Select food item: pizza
# Enter quantity: 5
# Food bill is: 500
# FINAL BILL
# Movie: avengers
# Tickets: 2
# Movie bill: 300
# Food: pizza
# Food bill: 500
# Total bill: 800
